# %% [markdown]
# <a href="https://colab.research.google.com/github/SydAt1/Eye_Disease_Classification/blob/main/notebooks/01_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('NHIS_eye_dataset.csv')
df.sample(5)
# Out:
#       YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 608        2016     2017           US     National       NHIS
# 8783       2016     2017           US     National       NHIS
# 9072       2016     2017           US     National       NHIS
# 2361       2016     2017           US     National       NHIS
# 8714       2016     2017           US     National       NHIS
#
#                       Topic                                      Category  \
# 608   Eye Health Conditions  Self-Report Age Related Macular Degeneration
# 8783    Service Utilization                                Eye Protection
# 9072    Service Utilization                                Eye Protection
# 2361  Eye Health Conditions              Self-Report Diabetic Retinopathy
# 8714    Service Utilization                                Eye Protection
#
#                                                Question          Response  \
# 608   Percentage of adults ever told by a doctor or ...               Yes
# 8783  Proportion of adults who participate in activi...           Refused
# 9072  Proportion of adults who participate in activi...  Some of the time
# 2361  Percentage of adults ever told by a doctor or ...               Yes
# 8714  Proportion of adults who participate in activi...           Refused
#
#                      Age  ... ResponseID DataValueTypeID      AgeID SexID  \
# 608          40-64 years  ...       RYES         CRDPREV    AGE4064    GM
# 8783  85 years and older  ...        RRF         CRDPREV  AGE85PLUS    GM
# 9072  18 years and older  ...      RSOMT         CRDPREV  AGE18PLUS    GF
# 2361         40-64 years  ...       RYES         CRDPREV    AGE4064  GALL
# 8714         65-84 years  ...        RRF         CRDPREV    AGE6584    GM
#
#      RaceEthnicityID RiskFactorID  RiskFactorResponseID GeoLocation  \
# 608              BLK         RFHT                 RFYES         NaN
# 8783             BLK         RFHT                  RFNO         NaN
# 9072             ASN         RFDM                 RFYES         NaN
# 2361             BLK         RFDM                  RFNO         NaN
# 8714             WHT       RFAPAR                 RFTOT         NaN
#
#      Geographic Level  StateAbbreviation
# 608          National                 US
# 8783         National                 US
# 9072         National                 US
# 2361         National                 US
# 8714         National                 US
#
# [5 rows x 37 columns]

# %% [markdown]
# Simply removing all the Null values here can result in wiping a large portion of rows of the dataset.

# %%
# Drop columns that have zero data
df = df.drop(columns=['Numerator', 'GeoLocation'])

# %%
df.isna().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# DataSource                        0
# Topic                             0
# Category                          0
# Question                          0
# Response                          0
# Age                               0
# Sex                               0
# RaceEthnicity                     0
# RiskFactor                        0
# RiskFactorResponse                0
# Data_Value_Unit                   0
# Data_Value_Type                   0
# Data_Value                        0
# Data_Value_Footnote_Symbol    11295
# Data_Value_Footnote           11295
# Low_Confidence_Limit              0
# High_Confidence_Limit             0
# Sample_Size                       0
# LocationID                        0
# TopicID                           0
# CategoryID                        0
# QuestionID                        0
# ResponseID                        0
# DataValueTypeID                   0
# AgeID                             0
# SexID                             0
# RaceEthnicityID                   0
# RiskFactorID                      0
# RiskFactorResponseID              0
# Geographic Level                  0
# StateAbbreviation                 0
# dtype: int64

# %%
# Drop rows only if the actual results (Data_Value) are missing
df_model = df.dropna(subset=['Data_Value']).copy()

# %% [markdown]
# 1. What is Data_Value?
#
# The Data_Value column is the primary metric of this dataset. It represents the statistical result for a specific survey question (e.g., "Difficulty seeing even when wearing glasses").
#
#   * Type: Usually a percentage (Prevalence) or a crude rate.
#
#   * Context: It must be interpreted alongside Data_Value_Unit (%) and Data_Value_Type (e.g., Age-adjusted Prevalence).

# %%
# To see all unique footnotes in the dataset
df_model['Data_Value'].unique()
# Out:
# array([ 2.74,  2.34,  5.25, ..., 48.5 , 46.5 , 39.6 ])

# %% [markdown]
# The target variable `Data_Value` represents the prevalence of eye disease at a population level. The model uses demographic factors, risk factors, geographic location, and temporal information to predict variations in eye disease prevalence.

# %%
df_model.shape[0]
# Out:
# 11295

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11295 entries, 0 to 23740
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   11295 non-null  int64
#  1   YearEnd                     11295 non-null  int64
#  2   LocationAbbr                11295 non-null  object
#  3   LocationDesc                11295 non-null  object
#  4   DataSource                  11295 non-null  object
#  5   Topic                       11295 non-null  object
#  6   Category                    11295 non-null  object
#  7   Question                    11295 non-null  object
#  8   Response                    11295 non-null  object
#  9   Age                         11295 non-null  object
#  10  Sex                         11295 non-null  object
#  11  RaceEthnicity               11295 non-null  object
#  12  RiskFactor                  11295 non-null  object
#  13  RiskFactorResponse          11295 non-null  object
#  14  Data_Value_Unit             11295 non-null  object
#  15  Data_Value_Type             11295 non-null  object
#  16  Data_Value                  11295 non-null  float64
#  17  Data_Value_Footnote_Symbol  0 non-null      object
#  18  Data_Value_Footnote         0 non-null      object
#  19  Low_Confidence_Limit        11295 non-null  float64
#  20  High_Confidence_Limit       11295 non-null  float64
#  21  Sample_Size                 11295 non-null  float64
#  22  LocationID                  11295 non-null  float64
#  23  TopicID                     11295 non-null  object
#  24  CategoryID                  11295 non-null  object
#  25  QuestionID                  11295 non-null  object
#  26  ResponseID                  11295 non-null  object
#  27  DataValueTypeID             11295 non-null  object
#  28  AgeID                       11295 non-null  object
#  29  SexID                       11295 non-null  object
#  30  RaceEthnicityID             11295 non-null  object
#  31  RiskFactorID                11295 non-null  object
#  32  RiskFactorResponseID        11295 non-null  object
#  33  Geographic Level            11295 non-null  object
#  34  StateAbbreviation           11295 non-null  object
# dtypes: float64(5), int64(2), object(28)
# memory usage: 3.1+ MB

# %%
# Remove the columns that aren't 'features' (like footnotes or empty columns)
cols_to_keep = ['YearStart', 'LocationAbbr', 'Age', 'Sex', 'RaceEthnicity', 'Question', 'Data_Value', 'RiskFactorID', 'RiskFactorResponseID']
df_model = df_model[cols_to_keep]

# %% [markdown]
# To predict prevalence or health outcomes, we need a mix of demographics (who they are), geography (where they are), and medical context (what other risks they have).
#
# Here is why the selected columns are the "Engine" of the Machine Learning model:
#
# #### The Target Variable
#
# * Data_Value: This is the Label. It is the specific percentage or rate which is to be predicted. Without this, the model has no "answer key" to learn from.
#
# #### The Features (Predictors)
# * Age, Sex, RaceEthnicity: These are the Primary Biological Predictors. Most eye conditions (like cataracts or macular degeneration) are heavily dependent on age and sometimes vary significantly by gender or genetic background.
#
# * RiskFactorID & RiskFactorResponseID: These are the Clinical Predictors. Conditions like Diabetes or Smoking status are high-impact drivers of eye health. These columns tell the model why a certain group might have higher vision loss than another group of the same age.
#
# * Question: This is the Context Feature. Since your dataset contains multiple types of eye conditions, this tells the model which specific condition the Data_Value refers to.
#
# * LocationAbbr: This is the Environmental Predictor. It captures geographic disparities, such as differences in state-level healthcare access or regional environmental factors.
#
# * YearStart: This is the Temporal Predictor. It helps the model account for trends over time, such as improvements in medical technology or changes in survey methods.

# %%
df_model.sample(5)
# Out:
#        YearStart LocationAbbr                 Age         Sex  \
# 17215       2016           US         65-84 years  Both sexes
# 9785        2016           US          0-17 years  Both sexes
# 22206       2016           US  85 years and older  Both sexes
# 18335       2016           US  85 years and older  Both sexes
# 12000       2016           US  18 years and older      Female
#
#                RaceEthnicity  \
# 17215    White, non-Hispanic
# 9785     White, non-Hispanic
# 22206              All races
# 18335              All races
# 12000  North American Native
#
#                                                 Question  Data_Value  \
# 17215  Percentage of adults who even when wearing gla...        5.83
# 9785   Percentage of children (ages 6-17) who partici...       12.08
# 22206  Percentage of adults who even when wearing gla...        0.28
# 18335  Percentage of adults who even when wearing gla...       53.95
# 12000  Percentage of adults who currently wear eyegla...       81.35
#
#       RiskFactorID RiskFactorResponseID
# 17215         RFHT                 RFNO
# 9785        RFAPAR                RFTOT
# 22206         RFSM                RFNEV
# 18335         RFHT                RFYES
# 12000         RFSM               RFFORM

# %%
df_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11295 entries, 0 to 23740
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   YearStart             11295 non-null  int64
#  1   LocationAbbr          11295 non-null  object
#  2   Age                   11295 non-null  object
#  3   Sex                   11295 non-null  object
#  4   RaceEthnicity         11295 non-null  object
#  5   Question              11295 non-null  object
#  6   Data_Value            11295 non-null  float64
#  7   RiskFactorID          11295 non-null  object
#  8   RiskFactorResponseID  11295 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 882.4+ KB
