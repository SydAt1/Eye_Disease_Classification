# %%
import pandas as pd

# %%
df = pd.read_csv('../dataset/NHIS_eye_dataset.csv')
df.sample(5)
# Out:
#        YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 71357       2014     2015           US     National       NHIS
# 37666       2016     2017           US     National       NHIS
# 11535       2016     2017           US     National       NHIS
# 16559       2016     2017           US     National       NHIS
# 24944       2016     2017           US     National       NHIS
#
#                      Topic                         Category  \
# 71357      Visual Function       Blind or Difficulty Seeing
# 37666      Visual Function    Near-Distance Visual Function
# 11535  Service Utilization  Eye Health Provider Interaction
# 16559      Visual Function     Far-Distance Visual Function
# 24944      Visual Function                     Visual Field
#
#                                                 Question  \
# 71357  Percentage of people who have (no, some, a lot...
# 37666  Percentage of adults who even when wearing gla...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71649 entries, 0 to 71648
# Data columns (total 37 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   71649 non-null  int64
#  1   YearEnd                     71649 non-null  int64
#  2   LocationAbbr                71649 non-null  object
#  3   LocationDesc                71649 non-null  object
#  4   DataSource                  71649 non-null  object
#  5   Topic                       71649 non-null  object
#  6   Category                    71649 non-null  object
#  7   Question                    71649 non-null  object
#  8   Response                    71649 non-null  object
#  9   Age                         71649 non-null  object
#  10  Sex                         71649 non-null  object
#  11  RaceEthnicity               71649 non-null  object
#  12  RiskFactor                  71649 non-null  object
# ...
